# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install deepxde
import re

import deepxde as dde
import matplotlib.pyplot as plt
import numpy as np
import scipy as sp
from scipy.integrate import odeint
from matplotlib import cm
import scipy.io
# Out:
# Collecting deepxde
#   Downloading DeepXDE-1.10.0-py3-none-any.whl (166 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.2/166.2 kB 4.4 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from deepxde) (3.7.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from deepxde) (1.23.5)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from deepxde) (1.2.2)
# Collecting scikit-optimize>=0.9.0 (from deepxde)
#   Downloading scikit_optimize-0.9.0-py2.py3-none-any.whl (100 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.3/100.3 kB 15.3 MB/s eta 0:00:00
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from deepxde) (1.11.3)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.10/dist-packages (from scikit-optimize>=0.9.0->deepxde) (1.3.2)
# Collecting pyaml>=16.9 (from scikit-optimize>=0.9.0->deepxde)
#   Downloading pyaml-23.9.7-py3-none-any.whl (23 kB)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->deepxde) (3.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->deepxde) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->deepxde) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->deepxde) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->deepxde) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->deepxde) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->deepxde) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->deepxde) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->deepxde) (2.8.2)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from pyaml>=16.9->scikit-optimize>=0.9.0->deepxde) (6.0.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->deepxde) (1.16.0)
# Installing collected packages: pyaml, scikit-optimize, deepxde
# Successfully installed deepxde-1.10.0 pyaml-23.9.7 scikit-optimize-0.9.0
# No backend selected.
# Finding available backend...
# Using backend: tensorflow.compat.v1
# Other supported backends: tensorflow, pytorch, jax, paddle.
# paddle supports more examples now and is recommended.
# WARNING:tensorflow:From /usr/local/lib/python3.10/dist-packages/tensorflow/python/compat/v2_compat.py:108: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# Found tensorflow.compat.v1
# Setting the default backend to "tensorflow.compat.v1". You can change it in the ~/.deepxde/config.json file or export the DDE_BACKEND environment variable. Valid options are: tensorflow.compat.v1, tensorflow, pytorch, jax, paddle (all lowercase)
# Enable just-in-time compilation with XLA.

# %% [markdown]
# ## Safety PDE with data

# %%
import scipy.io

mat = scipy.io.loadmat('/content/drive/MyDrive/RL+PDE/data/observe_x_3d_MC_1000.mat')
# mat = scipy.io.loadmat('/content/drive/MyDrive/RL+PDE/data/observe_x_3d_MC_10.mat')
# mat = scipy.io.loadmat('/content/drive/MyDrive/RL+PDE/data/observe_x_3d_MC_100.mat')
# mat = scipy.io.loadmat('/content/drive/MyDrive/RL+PDE/data/observe_x_3d_GT_cont.mat')

obs_x = mat['observe_x']
obs_func = mat['observe_func']

# obs_x.shape # (1500, 3)
# obs_func.shape # (1500, 1)

# %%
a = 1400
b = 1500

hf = plt.figure()
ha = hf.add_subplot(111, projection='3d')
ha.scatter(obs_x[a:b,1], obs_x[a:b,0], obs_func[a:b]) # X: time, Y: state
ha.set_xlabel(r'$\xi_2$')
ha.set_ylabel(r'$\xi_1$')
ha.set_title("Riccati ")
# Out:
# Text(0.5, 0.92, 'Riccati ')

# %%
# # pure data without ic
# a = 0
# b = 1500

# observe_x = obs_x[a:b]
# observe_x.shape # (9900, 3)
# # observe_x

# observe_func = obs_func[a:b]
# observe_func

# %%
# ic = np.mgrid[1:8:0.05, 1:4:0.05, 1.5:1.45:-0.1].reshape(3,-1).T
ic = np.mgrid[1:2:0.05, 1:2:0.05, 1.5:1.45:-0.1].reshape(3,-1).T
ic
(0.5*ic[:,0]**2 + 0.5*ic[:,1]**2) * 0.1
np.exp(0.1*(-0.5*ic[:,0]**2 - 0.5*ic[:,1]**2))
ic.shape # (8400, 3)
ic_func = np.exp(0.1*(-0.5*ic[:,0]**2 - 0.5*ic[:,1]**2))
ic_func = ic_func.reshape(-1,1)
ic_func.shape # (8400, 1)

a = 1000
b = 1500

observe_x = np.append(obs_x[a:b], ic, axis=0)
# observe_x = ic
observe_x.shape # (9900, 3)
# observe_x

observe_func = np.append(obs_func[a:b], ic_func, axis=0)
# observe_func = ic_func
observe_func
# Out:
# array([[0.68246946],
#        [0.67234807],
#        [0.65008758],
#        [0.6179864 ],
#        [0.60904062],
#        [0.58527865],
#        [0.56842549],
#        [0.55016779],
#        [0.51752228],
#        [0.49721702],
#        [0.67201668],
#        [0.65034734],
#        [0.62512699],
#        [0.61810776],
#        [0.59411073],
#        [0.5797846 ],
#        [0.54569929],
#        [0.52998011],
#        [0.50809519],
#        [0.47558883],
#        [0.64108229],
#        [0.62053781],
#        [0.61270897],
#        [0.59461986],
#        [0.56786527],
#        [0.55315712],
#        [0.53405674],
#        [0.50248357],
#        [0.49488123],
#        [0.46093918],
#        [0.62291618],
#        [0.60626067],
#        [0.59113302],
#        [0.57602685],
#        [0.54191236],
#        [0.5289401 ],
#        [0.50953628],
#        [0.48354437],
#        [0.4727853 ],
#        [0.45011239],
#        [0.60786544],
#        [0.57930797],
#        [0.55902514],
#        [0.5591612 ],
#        [0.53873466],
#        [0.51268738],
#        [0.49252209],
#        [0.4747825 ],
#        [0.45783687],
#        [0.43873468],
#        [0.57539877],
#        [0.56154692],
#        [0.54491787],
#        [0.52784648],
#        [0.50890716],
#        [0.49240838],
#        [0.47725896],
#        [0.46980846],
#        [0.44475815],
#        [0.41258899],
#        [0.54769642],
#        [0.54485228],
#        [0.51781803],
#        [0.50906859],
#        [0.49101252],
#        [0.46965325],
#        [0.46116757],
#        [0.43082078],
#        [0.42471452],
#        [0.39892595],
#        [0.52847945],
#        [0.51947163],
#        [0.50536966],
#        [0.48877534],
#        [0.47719755],
#        [0.45698287],
#        [0.43312858],
#        [0.42397005],
#        [0.40063297],
#        [0.38634186],
#        [0.51549348],
#        [0.49554909],
#        [0.47744475],
#        [0.46247467],
#        [0.45518056],
#        [0.43493015],
#        [0.42035477],
#        [0.40310347],
#        [0.39246976],
#        [0.36774271],
#        [0.48763545],
#        [0.46754286],
#        [0.45531485],
#        [0.4433144 ],
#        [0.43051442],
#        [0.41576375],
#        [0.39628273],
#        [0.38183487],
#        [0.37026094],
#        [0.34874127],
#        [0.73468654],
#        [0.72516933],
#        [0.70740367],
#        [0.69363541],
#        [0.66562208],
#        [0.65097348],
#        [0.63003894],
#        [0.60463034],
#        [0.59122919],
#        [0.56687807],
#        [0.72973868],
#        [0.70315694],
#        [0.69241023],
#        [0.67724247],
#        [0.64122479],
#        [0.63761972],
#        [0.61788324],
#        [0.59287523],
#        [0.57078966],
#        [0.55276769],
#        [0.7124568 ],
#        [0.69387395],
#        [0.6722552 ],
#        [0.65614085],
#        [0.64055805],
#        [0.6091029 ],
#        [0.60464117],
#        [0.58622765],
#        [0.54911804],
#        [0.53895123],
#        [0.68298124],
#        [0.66803983],
#        [0.65842982],
#        [0.64006709],
#        [0.62169929],
#        [0.6060908 ],
#        [0.58486895],
#        [0.56292308],
#        [0.54570988],
#        [0.52749996],
#        [0.66601609],
#        [0.65081676],
#        [0.63760691],
#        [0.62422115],
#        [0.59955637],
#        [0.59030603],
#        [0.56700363],
#        [0.54599682],
#        [0.52326652],
#        [0.51081126],
#        [0.64630896],
#        [0.62898135],
#        [0.6175717 ],
#        [0.59650689],
#        [0.58691346],
#        [0.56960114],
#        [0.54075077],
#        [0.52894345],
#        [0.51294417],
#        [0.48808364],
#        [0.62019521],
#        [0.61306779],
#        [0.59012817],
#        [0.57515272],
#        [0.56649219],
#        [0.55184459],
#        [0.53182106],
#        [0.50269164],
#        [0.5008318 ],
#        [0.47065949],
#        [0.5976245 ],
#        [0.59257607],
#        [0.58462261],
#        [0.56559328],
#        [0.54816697],
#        [0.52892382],
#        [0.51324113],
#        [0.49696203],
#        [0.47808422],
#        [0.45441162],
#        [0.58697278],
#        [0.56322898],
#        [0.55830668],
#        [0.5421099 ],
#        [0.53404627],
#        [0.50846964],
#        [0.49402096],
#        [0.47814458],
#        [0.46001308],
#        [0.43871781],
#        [0.55966436],
#        [0.54487378],
#        [0.53010519],
#        [0.52086363],
#        [0.50329602],
#        [0.49086244],
#        [0.47355792],
#        [0.46560361],
#        [0.43960883],
#        [0.42981821],
#        [0.78857211],
#        [0.78316746],
#        [0.76266087],
#        [0.75178937],
#        [0.72885189],
#        [0.70563786],
#        [0.69798688],
#        [0.67437072],
#        [0.65765283],
#        [0.63641948],
#        [0.7787417 ],
#        [0.76711182],
#        [0.74935013],
#        [0.73101733],
#        [0.72224418],
#        [0.69882113],
#        [0.6802893 ],
#        [0.6656828 ],
#        [0.65037803],
#        [0.62692655],
#        [0.76186857],
#        [0.74635926],
#        [0.73730418],
#        [0.71705831],
#        [0.70441242],
#        [0.68935233],
#        [0.67827485],
#        [0.65005444],
#        [0.62333271],
#        [0.61039168],
#        [0.74873765],
#        [0.73531974],
#        [0.72024683],
#        [0.70610245],
#        [0.69117926],
#        [0.67268151],
#        [0.65316311],
#        [0.63210914],
#        [0.62050808],
#        [0.60181358],
#        [0.7326437 ],
#        [0.72003252],
#        [0.705029  ],
#        [0.68578688],
#        [0.67618335],
#        [0.65864924],
#        [0.63532344],
#        [0.62151614],
#        [0.60323519],
#        [0.582526  ],
#        [0.71046866],
#        [0.6925932 ],
#        [0.68150461],
#        [0.6655924 ],
#        [0.65134153],
#        [0.64229293],
#        [0.62407161],
#        [0.60728839],
#        [0.58352384],
#        [0.57370807],
#        [0.69428671],
#        [0.68134351],
#        [0.66600845],
#        [0.65019131],
#        [0.64417459],
#        [0.62136983],
#        [0.61209505],
#        [0.58815093],
#        [0.57052868],
#        [0.55030301],
#        [0.67106763],
#        [0.65624308],
#        [0.64828742],
#        [0.63041831],
#        [0.61715875],
#        [0.60502284],
#        [0.58653733],
#        [0.5699297 ],
#        [0.55851052],
#        [0.5337428 ],
#        [0.65375516],
#        [0.64038172],
#        [0.63327844],
#        [0.61615033],
#        [0.59761027],
#        [0.58702531],
#        [0.56578813],
#        [0.55058894],
#        [0.54207889],
#        [0.51876768],
#        [0.63194169],
#        [0.61797452],
#        [0.61148224],
#        [0.59124974],
#        [0.58584385],
#        [0.55743132],
#        [0.55624072],
#        [0.53462244],
#        [0.52474686],
#        [0.50689349],
#        [0.84618174],
#        [0.82795961],
#        [0.81553701],
#        [0.80472628],
#        [0.78949448],
#        [0.77257496],
#        [0.7590925 ],
#        [0.73843315],
#        [0.72037962],
#        [0.72860393],
#        [0.72162476],
#        [0.82324618],
#        [0.81903783],
#        [0.81464732],
#        [0.81007779],
#        [0.80533253],
#        [0.80041495],
#        [0.79532853],
#        [0.7900769 ],
#        [0.78466375],
#        [0.77909289],
#        [0.77336821],
#        [0.76749371],
#        [0.76147343],
#        [0.75531152],
#        [0.74901221],
#        [0.74257975],
#        [0.73601852],
#        [0.7293329 ],
#        [0.72252735],
#        [0.71560639],
#        [0.81617621],
#        [0.81200401],
#        [0.8076512 ],
#        [0.80312091],
#        [0.79841641],
#        [0.79354106],
#        [0.78849832],
#        [0.78329179],
#        [0.77792512],
#        [0.77240211],
#        [0.7667266 ],
#        [0.76090254],
#        [0.75493396],
#        [0.74882498],
#        [0.74257975],
#        [0.73620255],
#        [0.72969766],
#        [0.72306945],
#        [0.71632235],
#        [0.70946082],
#        [0.8089647 ],
#        [0.80482936],
#        [0.80051501],
#        [0.79602475],
#        [0.79136182],
#        [0.78652954],
#        [0.78153136],
#        [0.77637083],
#        [0.77105159],
#        [0.76557737],
#        [0.759952  ],
#        [0.75417941],
#        [0.74826357],
#        [0.74220856],
#        [0.73601852],
#        [0.72969766],
#        [0.72325024],
#        [0.7166806 ],
#        [0.70999312],
#        [0.70319222],
#        [0.80161647],
#        [0.7975187 ],
#        [0.79324353],
#        [0.78879406],
#        [0.78417349],
#        [0.7793851 ],
#        [0.77443233],
#        [0.76931867],
#        [0.76404774],
#        [0.75862325],
#        [0.75304899],
#        [0.74732882],
#        [0.74146672],
#        [0.73546671],
#        [0.7293329 ],
#        [0.72306945],
#        [0.7166806 ],
#        [0.71017064],
#        [0.7035439 ],
#        [0.69680478],
#        [0.79413644],
#        [0.7900769 ],
#        [0.78584163],
#        [0.78143368],
#        [0.77685621],
#        [0.77211251],
#        [0.76720595],
#        [0.76214001],
#        [0.75691827],
#        [0.75154439],
#        [0.74602214],
#        [0.74035535],
#        [0.73454795],
#        [0.72860393],
#        [0.72252735],
#        [0.71632235],
#        [0.70999312],
#        [0.7035439 ],
#        [0.696979  ],
#        [0.69030276],
#        [0.78652954],
#        [0.78250889],
#        [0.77831418],
#        [0.77394846],
#        [0.76941484],
#        [0.76471658],
#        [0.75985702],
#        [0.7548396 ],
#        [0.74966788],
#        [0.74434548],
#        [0.73887612],
#        [0.73326362],
#        [0.72751184],
#        [0.72162476],
#        [0.71560639],
#        [0.70946082],
#        [0.70319222],
#        [0.69680478],
#        [0.69030276],
#        [0.68369047]])

# %% [markdown]
# ### Fixed PDE

# %%
def pde(x, y):
    dy_t = dde.grad.jacobian(y, x, j=2)
    dy_x1 = dde.grad.jacobian(y, x, j=0)
    dy_xx1 = dde.grad.hessian(y, x, i=0)
    dy_x2 = dde.grad.jacobian(y, x, j=1)
    dy_xx2 = dde.grad.hessian(y, x, i=1, j=1)
    # Backend tensorflow.compat.v1 or tensorflow
    return (
        dy_t
        + x[:, 0:1] * dy_x1
        + x[:, 1:2] * dy_x2
        + dy_xx1
        + 0.5 * dy_xx2
        - 0.1*(0.5*x[:, 0:1]**2 + 0.5*x[:, 1:2]**2) * y
    )

# %% [markdown]
# ### Varying PDE

# %%
observe_y = dde.icbc.PointSetBC(observe_x, observe_func, component=0)

geom = dde.geometry.geometry_2d.Rectangle([1,1],[2,2])
timedomain = dde.geometry.TimeDomain(0, 1.5)
geomtime = dde.geometry.GeometryXTime(geom, timedomain)

data = dde.data.TimePDE(
    geomtime,
    pde,
    [observe_y],
    num_domain=0,
    # num_domain=600,
    # num_boundary=20,
    # num_initial=10,
    anchors=observe_x,
)

# %%
layer_size = [3] + [32] * 3 + [1]
activation = "tanh"
initializer = "Glorot uniform"
net = dde.nn.FNN(layer_size, activation, initializer)

model = dde.Model(data, net)

model.compile(
    "adam", lr=0.001, external_trainable_variables=[]
)
variable = dde.callbacks.VariableValue([], period=1000)
model.train(epochs=60000, callbacks=[variable])
# Out:
# Compiling model...
# Warning: For the backend tensorflow.compat.v1, `external_trainable_variables` is ignored, and all trainable ``tf.Variable`` objects are automatically collected.
# Building feed-forward neural network...
# 'build' took 0.057860 s
# /usr/local/lib/python3.10/dist-packages/deepxde/nn/tensorflow_compat_v1/fnn.py:116: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   return tf.layers.dense(
# 'compile' took 2.929280 s
#
# Warning: epochs is deprecated and will be removed in a future version. Use iterations instead.
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 0         [1.64e-02, 4.66e-01]    [1.64e-02, 4.66e-01]    []
# 0 []
# 1000      [9.99e-05, 3.27e-05]    [9.99e-05, 3.27e-05]    []
# 1000 []
# 2000      [2.89e-05, 1.48e-05]    [2.89e-05, 1.48e-05]    []
# 2000 []
# 3000      [1.54e-05, 1.31e-05]    [1.54e-05, 1.31e-05]    []
# 3000 []
# 4000      [9.83e-06, 1.22e-05]    [9.83e-06, 1.22e-05]    []
# 4000 []
# 5000      [7.03e-06, 1.47e-05]    [7.03e-06, 1.47e-05]    []
# 5000 []
# 6000      [5.50e-06, 1.16e-05]    [5.50e-06, 1.16e-05]    []
# 6000 []
# 7000      [4.41e-06, 1.14e-05]    [4.41e-06, 1.14e-05]    []
# 7000 []
# 8000      [3.64e-06, 1.39e-04]    [3.64e-06, 1.39e-04]    []
# 8000 []
# 9000      [3.31e-06, 1.75e-05]    [3.31e-06, 1.75e-05]    []
# 9000 []
# 10000     [2.84e-06, 1.11e-05]    [2.84e-06, 1.11e-05]    []
# 10000 []
# 11000     [2.49e-06, 1.10e-05]    [2.49e-06, 1.10e-05]    []
# 11000 []
# 12000     [2.24e-06, 1.09e-05]    [2.24e-06, 1.09e-05]    []
# 12000 []
# 13000     [2.00e-06, 1.07e-05]    [2.00e-06, 1.07e-05]    []
# 13000 []
# 14000     [1.83e-06, 1.06e-05]    [1.83e-06, 1.06e-05]    []
# 14000 []
# 15000     [1.73e-06, 1.07e-05]    [1.73e-06, 1.07e-05]    []
# 15000 []
# 16000     [1.71e-06, 1.05e-05]    [1.71e-06, 1.05e-05]    []
# 16000 []
# 17000     [1.66e-06, 1.04e-05]    [1.66e-06, 1.04e-05]    []
# 17000 []
# 18000     [1.90e-06, 1.04e-05]    [1.90e-06, 1.04e-05]    []
# 18000 []
# 19000     [1.58e-06, 1.03e-05]    [1.58e-06, 1.03e-05]    []
# 19000 []
# 20000     [1.54e-06, 1.03e-05]    [1.54e-06, 1.03e-05]    []
# 20000 []
# 21000     [1.47e-06, 1.02e-05]    [1.47e-06, 1.02e-05]    []
# 21000 []
# 22000     [1.43e-06, 1.02e-05]    [1.43e-06, 1.02e-05]    []
# 22000 []
# 23000     [1.34e-06, 1.01e-05]    [1.34e-06, 1.01e-05]    []
# 23000 []
# 24000     [1.54e-06, 1.05e-05]    [1.54e-06, 1.05e-05]    []
# 24000 []
# 25000     [3.43e-05, 6.11e-05]    [3.43e-05, 6.11e-05]    []
# 25000 []
# 26000     [1.41e-05, 1.23e-04]    [1.41e-05, 1.23e-04]    []
# 26000 []
# 27000     [1.12e-05, 2.92e-05]    [1.12e-05, 2.92e-05]    []
# 27000 []
# 28000     [9.36e-07, 9.97e-06]    [9.36e-07, 9.97e-06]    []
# 28000 []
# 29000     [8.65e-07, 9.93e-06]    [8.65e-07, 9.93e-06]    []
# 29000 []
# 30000     [1.50e-06, 3.55e-05]    [1.50e-06, 3.55e-05]    []
# 30000 []
# 31000     [7.13e-07, 9.86e-06]    [7.13e-07, 9.86e-06]    []
# 31000 []
# 32000     [8.07e-07, 9.92e-06]    [8.07e-07, 9.92e-06]    []
# 32000 []
# 33000     [5.89e-07, 9.78e-06]    [5.89e-07, 9.78e-06]    []
# 33000 []
# 34000     [5.40e-07, 9.75e-06]    [5.40e-07, 9.75e-06]    []
# 34000 []
# 35000     [5.05e-07, 9.76e-06]    [5.05e-07, 9.76e-06]    []
# 35000 []
# 36000     [4.75e-07, 9.71e-06]    [4.75e-07, 9.71e-06]    []
# 36000 []
# 37000     [5.37e-07, 1.09e-05]    [5.37e-07, 1.09e-05]    []
# 37000 []
# 38000     [1.04e-06, 9.55e-06]    [1.04e-06, 9.55e-06]    []
# 38000 []
# 39000     [1.30e-06, 9.58e-06]    [1.30e-06, 9.58e-06]    []
# 39000 []
# 40000     [5.59e-07, 1.30e-05]    [5.59e-07, 1.30e-05]    []
# 40000 []
# 41000     [4.81e-06, 9.39e-06]    [4.81e-06, 9.39e-06]    []
# 41000 []
# 42000     [3.74e-07, 9.53e-06]    [3.74e-07, 9.53e-06]    []
# 42000 []
# 43000     [2.58e-06, 9.37e-06]    [2.58e-06, 9.37e-06]    []
# 43000 []
# 44000     [4.67e-07, 9.49e-06]    [4.67e-07, 9.49e-06]    []
# 44000 []
# 45000     [3.15e-07, 9.44e-06]    [3.15e-07, 9.44e-06]    []
# 45000 []
# 46000     [3.11e-07, 9.41e-06]    [3.11e-07, 9.41e-06]    []
# 46000 []
# 47000     [3.59e-07, 9.38e-06]    [3.59e-07, 9.38e-06]    []
# 47000 []
# 48000     [4.31e-07, 9.49e-06]    [4.31e-07, 9.49e-06]    []
# 48000 []
# 49000     [1.22e-05, 3.17e-05]    [1.22e-05, 3.17e-05]    []
# 49000 []
# 50000     [2.94e-07, 9.37e-06]    [2.94e-07, 9.37e-06]    []
# 50000 []
# 51000     [3.27e-07, 9.38e-06]    [3.27e-07, 9.38e-06]    []
# 51000 []
# 52000     [2.64e-07, 9.32e-06]    [2.64e-07, 9.32e-06]    []
# 52000 []
# 53000     [2.74e-07, 9.61e-06]    [2.74e-07, 9.61e-06]    []
# 53000 []
# 54000     [7.49e-07, 9.41e-06]    [7.49e-07, 9.41e-06]    []
# 54000 []
# 55000     [2.91e-07, 9.71e-06]    [2.91e-07, 9.71e-06]    []
# 55000 []
# 56000     [3.21e-07, 9.56e-06]    [3.21e-07, 9.56e-06]    []
# 56000 []
# 57000     [3.42e-07, 9.23e-06]    [3.42e-07, 9.23e-06]    []
# 57000 []
# 58000     [2.39e-07, 9.25e-06]    [2.39e-07, 9.25e-06]    []
# 58000 []
# 59000     [4.27e-06, 1.00e-05]    [4.27e-06, 1.00e-05]    []
# 59000 []
# 60000     [2.18e-07, 9.21e-06]    [2.18e-07, 9.21e-06]    []
# 60000 []
#
# Best model at step 60000:
#   train loss: 9.43e-06
#   test loss: 9.43e-06
#   test metric: []
#
# 'train' took 84.956933 s
# (<deepxde.model.LossHistory at 0x7eabfc44f820>,
#  <deepxde.model.TrainState at 0x7eabfc44c430>)

# %%
import scipy.io

mat0 = scipy.io.loadmat('/content/drive/MyDrive/RL+PDE/data/observe_x_3d_10000.mat')

obs0_x = mat0['observe_x']
obs0_func = mat0['observe_func']

# %%
test_x = obs0_x
test_x.shape

yhat = model.predict(test_x)

yhat.shape

difference = yhat - obs0_func

# %%
a = 500
b = 600

import matplotlib
matplotlib.rcParams.update({'font.size': 13})

hf = plt.figure()
ha = hf.add_subplot(111, projection='3d')
ha.scatter(obs0_x[a:b,1], obs0_x[a:b,0], obs0_func[a:b]) # X: time, Y: state
ha.set_xlabel(r'$\xi_2$')
ha.set_ylabel(r'$\xi_1$')
ha.set_title("Riccati GT")
plt.savefig("Riccati GT.pdf")

hf = plt.figure()
ha = hf.add_subplot(111, projection='3d')
ha.scatter(obs0_x[a:b,1], obs0_x[a:b,0], yhat[a:b]) # X: time, Y: state
ha.set_xlabel(r'$\xi_2$')
ha.set_ylabel(r'$\xi_1$')
ha.set_title("Prediction")
plt.savefig("Prediction.pdf")

hf = plt.figure()
ha = hf.add_subplot(111, projection='3d')
ha.scatter(obs0_x[a:b,1], obs0_x[a:b,0], yhat[a:b]-obs0_func[a:b]) # X: time, Y: state
ha.set_xlabel(r'$\xi_2$')
ha.set_ylabel(r'$\xi_1$')
ha.set_title("Difference")
plt.savefig("Difference.pdf")
plt.show()

# %%
# percentage error
np.mean(np.divide(abs(difference[a:b]), obs0_func[a:b]))
# Out:
# 0.05672351656412729

# %%
# absolute error
np.mean(abs(difference[a:b]))
# Out:
# 0.021504815872062908

# %%
c = 1500 - b
d = 1500 - a

import matplotlib
matplotlib.rcParams.update({'font.size': 13})

hf = plt.figure()
ha = hf.add_subplot(111, projection='3d')
ha.scatter(obs_x[c:d,1], obs_x[c:d,0], obs_func[c:d]) # X: time, Y: state
ha.set_xlabel(r'$\xi_2$')
ha.set_ylabel(r'$\xi_1$')
ha.set_title("Riccati")
plt.savefig("Riccati.pdf")

hf = plt.figure()
ha = hf.add_subplot(111, projection='3d')
ha.scatter(obs0_x[a:b,1], obs0_x[a:b,0], yhat[a:b]) # X: time, Y: state
ha.set_xlabel(r'$\xi_2$')
ha.set_ylabel(r'$\xi_1$')
ha.set_title("Prediction")
plt.savefig("Prediction.pdf")
